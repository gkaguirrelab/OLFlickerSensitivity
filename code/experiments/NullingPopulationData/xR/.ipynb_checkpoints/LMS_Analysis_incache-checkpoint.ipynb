# %%
library(lmerTest)
library(ggplot2)
options(width=150)
# Out:
# Loading required package: Matrix
# Loading required package: lme4
#
# Attaching package: ‘lmerTest’
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
mydata = read.csv("/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_AllNullingContrast.csv")
mydata$Run <- factor(mydata$Run)
mydata$Run <- gsub('1', 'Run 1', mydata$Run)
mydata$Run <- gsub('2', 'Run 2', mydata$Run)
mydata$Arm <- factor(mydata$Arm)
mydata$Arm <- gsub('1', 'Positive', mydata$Arm)
mydata$Arm <- gsub('2', 'Negative', mydata$Arm)
mydata$Group <- factor(mydata$Group)
mydata$Group <- gsub('NullingPopulationData18To24', '18-24 yrs', mydata$Group)
mydata$Group <- gsub('NullingPopulationDataFork2', '25-40 yrs', mydata$Group)

# %%
testLMinusM <- lmer(L.M.null ~ (1 | Subject) + Group + Arm + Run, data=mydata)
lsmeans(testLMinusM)
difflsmeans(testLMinusM)
fileName <- '/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_LMinusMNull_ANOVA.csv'
capture.output(lsmeans(testLMinusM), file=fileName)
capture.output(difflsmeans(testLMinusM), file=fileName, append=TRUE)
# Out:
# Least Squares Means table:
#                  Group  Arm  Run Estimate Standard Error   DF t-value Lower CI Upper CI p-value
# Group  18-24 yrs   1.0   NA   NA   0.0142         0.0018 30.0    8.10   0.0106   0.0178  <2e-16 ***
# Group  25-40 yrs   2.0   NA   NA   0.0155         0.0018 30.0    8.84   0.0119   0.0191  <2e-16 ***
# Arm  Negative       NA  1.0   NA   0.0139         0.0015 56.2    9.47   0.0110   0.0169  <2e-16 ***
# Arm  Positive       NA  2.0   NA   0.0158         0.0015 56.2   10.75   0.0129   0.0188  <2e-16 ***
# Run  Run 1          NA   NA  1.0   0.0146         0.0015 56.2    9.89   0.0116   0.0175  <2e-16 ***
# Run  Run 2          NA   NA  2.0   0.0152         0.0015 56.2   10.33   0.0123   0.0182  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Differences of LSMEANS:
#                             Estimate Standard Error DF t-value Lower CI Upper CI p-value
# Group 18-24 yrs - 25-40 yrs        0         0.0025 30   -0.52  -0.0064   0.0038     0.6
# Arm Negative - Positive            0         0.0016 94   -1.20  -0.0050   0.0012     0.2
# Run Run 1 - Run 2                  0         0.0016 94   -0.41  -0.0038   0.0025     0.7

# %%
testS <- lmer(S.null ~ (1 | Subject) + Group + Arm + Run, data=mydata)
lsmeans(testS)
difflsmeans(testS)
fileName <- '/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_SNull_ANOVA.csv'
capture.output(lsmeans(testS), file=fileName)
capture.output(difflsmeans(testS), file=fileName, append=TRUE)
# Out:
# Least Squares Means table:
#                  Group Arm Run Estimate Standard Error  DF t-value Lower CI Upper CI p-value
# Group  18-24 yrs     1  NA  NA  -0.0266         0.0051 124   -5.28  -0.0366  -0.0166  <2e-16 ***
# Group  25-40 yrs     2  NA  NA  -0.0325         0.0051 124   -6.44  -0.0425  -0.0225  <2e-16 ***
# Arm  Negative       NA   1  NA  -0.0445         0.0051 124   -8.81  -0.0545  -0.0345  <2e-16 ***
# Arm  Positive       NA   2  NA  -0.0147         0.0051 124   -2.91  -0.0247  -0.0047   0.004 **
# Run  Run 1          NA  NA   1  -0.0350         0.0051 124   -6.92  -0.0450  -0.0250  <2e-16 ***
# Run  Run 2          NA  NA   2  -0.0242         0.0051 124   -4.79  -0.0342  -0.0142  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Differences of LSMEANS:
#                             Estimate Standard Error  DF t-value Lower CI Upper CI p-value
# Group 18-24 yrs - 25-40 yrs        0         0.0071 124    0.82  -0.0082   0.0200     0.4
# Arm Negative - Positive            0         0.0071 124   -4.17  -0.0439  -0.0156   1e-04 ***
# Run Run 1 - Run 2                  0         0.0071 124   -1.51  -0.0249   0.0034     0.1
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
b2 <- plot(lsmeans(testLMinusM))
b2 + ggtitle("LMS directed / L-M null") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_LMinusMNull_ANOVA.pdf')
b3 <- plot(lsmeans(testS))
b3 + ggtitle("LMS directed / S null") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_SNull_ANOVA.pdf')
# Out:
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title

# %%
b2 <- plot(difflsmeans(testLMinusM))
b2 + ggtitle(c("LMS directed / L-M null\nDifference in means")) + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_LMinusMNull_ANOVA_DiffMeans.pdf')
b3 <- plot(difflsmeans(testS))
b3 + ggtitle("LMS directed / S null\nDifference in means") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/LMS_SNull_ANOVA_DiffMeans.pdf')
# Out:
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
