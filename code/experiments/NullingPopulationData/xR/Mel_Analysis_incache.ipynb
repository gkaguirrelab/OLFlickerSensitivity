# %%
library(lmerTest)
library(ggplot2)
options(width=150)
# Out:
# Loading required package: Matrix
# Loading required package: lme4
#
# Attaching package: ‘lmerTest’
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
mydata = read.csv("/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_AllNullingContrast.csv")
mydata$Run <- factor(mydata$Run)
mydata$Run <- gsub('1', 'Run 1', mydata$Run)
mydata$Run <- gsub('2', 'Run 2', mydata$Run)
mydata$Arm <- factor(mydata$Arm)
mydata$Arm <- gsub('1', 'Positive', mydata$Arm)
mydata$Arm <- gsub('2', 'Negative', mydata$Arm)
mydata$Group <- factor(mydata$Group)
mydata$Group <- gsub('NullingPopulationData18To24', '18-24 yrs', mydata$Group)
mydata$Group <- gsub('NullingPopulationDataFork2', '25-40 yrs', mydata$Group)

# %%
testLMS <- lmer(LMS.null ~ (1 | Subject) + Group + Arm + Run, data=mydata)
lsmeans(testLMS)
difflsmeans(testLMS)
fileName <- '/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_LMSNull_ANOVA.csv'
capture.output(lsmeans(testLMS), file=fileName)
capture.output(difflsmeans(testLMS), file=fileName, append=TRUE)
# Out:
# Least Squares Means table:
#                  Group Arm Run Estimate Standard Error  DF t-value Lower CI Upper CI p-value
# Group  18-24 yrs     1  NA  NA  -0.0101         0.0035 124   -2.93  -0.0169  -0.0033   0.004 **
# Group  25-40 yrs     2  NA  NA  -0.0087         0.0035 124   -2.51  -0.0155  -0.0018   0.013 *
# Arm  Negative       NA   1  NA  -0.0160         0.0035 124   -4.62  -0.0228  -0.0091  <2e-16 ***
# Arm  Positive       NA   2  NA  -0.0028         0.0035 124   -0.82  -0.0097   0.0040   0.414
# Run  Run 1          NA  NA   1  -0.0092         0.0035 124   -2.68  -0.0161  -0.0024   0.008 **
# Run  Run 2          NA  NA   2  -0.0095         0.0035 124   -2.76  -0.0164  -0.0027   0.007 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Differences of LSMEANS:
#                             Estimate Standard Error  DF t-value Lower CI Upper CI p-value
# Group 18-24 yrs - 25-40 yrs        0         0.0049 124   -0.29  -0.0111   0.0082   0.769
# ...

# %%
testLMinusM <- lmer(L.M.null ~ (1 | Subject) + Group + Arm + Run, data=mydata)
lsmeans(testLMinusM)
difflsmeans(testLMinusM)
fileName <- '/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_LMinusMNull_ANOVA.csv'
capture.output(lsmeans(testLMinusM), file=fileName)
capture.output(difflsmeans(testLMinusM), file=fileName, append=TRUE)
# Out:
# Least Squares Means table:
#                  Group  Arm  Run Estimate Standard Error   DF t-value Lower CI Upper CI p-value
# Group  18-24 yrs   1.0   NA   NA  -0.0132         0.0015 30.0   -8.70  -0.0163  -0.0101  <2e-16 ***
# Group  25-40 yrs   2.0   NA   NA  -0.0130         0.0015 30.0   -8.52  -0.0161  -0.0099  <2e-16 ***
# Arm  Negative       NA  1.0   NA  -0.0122         0.0011 38.1  -10.68  -0.0145  -0.0099  <2e-16 ***
# Arm  Positive       NA  2.0   NA  -0.0140         0.0011 38.1  -12.23  -0.0163  -0.0117  <2e-16 ***
# Run  Run 1          NA   NA  1.0  -0.0131         0.0011 38.1  -11.42  -0.0154  -0.0107  <2e-16 ***
# Run  Run 2          NA   NA  2.0  -0.0131         0.0011 38.1  -11.49  -0.0155  -0.0108  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Differences of LSMEANS:
#                             Estimate Standard Error   DF t-value Lower CI Upper CI p-value
# ...

# %%
testS <- lmer(S.null ~ (1 | Subject) + Group + Arm + Run, data=mydata)
lsmeans(testS)
difflsmeans(testS)
fileName <- '/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_SNull_ANOVA.csv'
capture.output(lsmeans(testS), file=fileName)
capture.output(difflsmeans(testS), file=fileName, append=TRUE)
# Out:
# Least Squares Means table:
#                  Group  Arm  Run Estimate Standard Error   DF t-value Lower CI Upper CI p-value
# Group  18-24 yrs   1.0   NA   NA   0.0096         0.0060 30.0    1.61  -0.0026   0.0219    0.12
# Group  25-40 yrs   2.0   NA   NA   0.0096         0.0060 30.0    1.60  -0.0026   0.0218    0.12
# Arm  Negative       NA  1.0   NA   0.0085         0.0056 76.9    1.52  -0.0026   0.0196    0.13
# Arm  Positive       NA  2.0   NA   0.0108         0.0056 76.9    1.93  -0.0003   0.0219    0.06 .
# Run  Run 1          NA   NA  1.0   0.0122         0.0056 76.9    2.19   0.0011   0.0233    0.03 *
# Run  Run 2          NA   NA  2.0   0.0070         0.0056 76.9    1.26  -0.0041   0.0181    0.21
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Differences of LSMEANS:
#                             Estimate Standard Error DF t-value Lower CI Upper CI p-value
# Group 18-24 yrs - 25-40 yrs        0         0.0085 30    0.00  -0.0173   0.0173     1.0
# ...

# %%
b1 <- plot(lsmeans(testLMS))
b1 + ggtitle("Mel directed / LMS null") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_LMSNull_ANOVA.pdf')
b2 <- plot(lsmeans(testLMinusM))
b2 + ggtitle("Mel directed / L-M null") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_LMinusMNull_ANOVA.pdf')
b3 <- plot(lsmeans(testS))
b3 + ggtitle("Mel directed / S null") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_SNull_ANOVA.pdf')
# Out:
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title

# %%
b1 <- plot(difflsmeans(testLMS))
b1 + ggtitle("Mel directed / LMS null\nDifference in means") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_LMSNull_ANOVA_DiffMeans.pdf')
b2 <- plot(difflsmeans(testLMinusM))
b2 + ggtitle("Mel directed / L-M null\nDifference in means") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_LMinusMNull_ANOVA_DiffMeans.pdf')
b3 <- plot(difflsmeans(testS))
b3 + ggtitle("Mel directed / S null\nDifference in means") + coord_cartesian(ylim=c(-0.08, 0.08)) + ylab('Contrast') + xlab('Groups') + theme(legend.position="none")
ggsave(file='/Users/mspits/Dropbox (Aguirre-Brainard Lab)/MELA_analysis/NullingPopulationData/xInCache/Mel_SNull_ANOVA.png_DiffMeans.pdf')
# Out:
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
